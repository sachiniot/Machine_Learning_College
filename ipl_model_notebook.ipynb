# %% [markdown]
# # IPL Match Winner Model (Step-by-Step)
# Run each cell and observe outputs.

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
import joblib

# %%
print("Step 1: Load dataset")
df = pd.read_csv('matches.csv')
df.head()
# Out:
# Step 1: Load dataset
#    match_id   season        city        date match_type player_of_match  \
# 0    335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1    335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2    335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3    335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4    335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
# ...

# %%
print("Step 2: Select features")
features = ['city', 'venue', 'team1', 'team2']
target = 'winner'
features, target
# Out:
# Step 2: Select features
# (['city', 'venue', 'team1', 'team2'], 'winner')

# %%
print("Step 3: Encoding")
le_dict = {}
for col in features:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))
    le_dict[col] = le
# Out:
# Step 3: Encoding

# %%
print("Step 4: Prepare X and y")
X = df[features]
target_le = LabelEncoder()
y = target_le.fit_transform(df[target])
# Out:
# Step 4: Prepare X and y

# %%
print("Step 5: Train model")
model = RandomForestClassifier(n_estimators=700 ,random_state=42)
model.fit(X, y)
print("Model trained")
# Out:
# Step 5: Train model
# Model trained

# %%
city = "Bangalore"
venue = "M Chinnaswamy Stadium"
team1 = "Royal Challengers Bangalore"
team2 = "Chennai Super Kings"

city_encoded = le_dict['city'].transform([city])[0]
venue_encoded = le_dict['venue'].transform([venue])[0]
team1_encoded = le_dict['team1'].transform([team1])[0]
team2_encoded = le_dict['team2'].transform([team2])[0]


input_data = [[city_encoded, venue_encoded, team1_encoded, team2_encoded]]


prediction = model.predict(input_data)


winner = target_le.inverse_transform(prediction)

print("Predicted Winner:", winner[0])
# Out:
# Predicted Winner: Royal Challengers Bangalore
# 0.8474885844748858
# C:\Users\Administrator\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
accuracy = model.score(X,y)
print(accuracy)
# Out:
# 0.8474885844748858

# %%
print("Step 6: Save model")
joblib.dump({
    'pipeline': model,
    'label_encoders': le_dict,
    'feature_names': features
}, 'ipl_model.pkl')
print("Model saved")
# Out:
# Step 6: Save model
# Model saved
