# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import make_pipeline

# %%
df=pd.read_csv("C:\\Users\\mukes\\OneDrive\\Documents\\ML\\ipl data set.csv")
df
# Out:
#        match_id batting_team bowling_team                   venue  \
# 0             1          CSK          RCB    Rajiv Gandhi Stadium
# 1             2          SRH           DC    Rajiv Gandhi Stadium
# 2             3          SRH         PBKS    Rajiv Gandhi Stadium
# 3             4         PBKS           RR        Wankhede Stadium
# 4             5         PBKS           GT  Sawai Mansingh Stadium
# ...         ...          ...          ...                     ...
# 34995     34996          LSG         PBKS    Arun Jaitley Stadium
# 34996     34997          CSK          SRH        Wankhede Stadium
# 34997     34998          LSG           GT        Wankhede Stadium
# 34998     34999          RCB           GT    Arun Jaitley Stadium
# 34999     35000          CSK          KKR            Eden Gardens
#
#              pitch_type pitch_condition  current_score  overs_completed  \
# 0              Balanced             Dry            133               12
# 1      Batting Friendly             Dry             76               16
# 2              Balanced           Green            126               13
# 3      Batting Friendly           Dusty             65               13
# 4      Bowling Friendly           Green             32                5
# ...                 ...             ...            ...              ...
# 34995          Balanced           Green            148               14
# 34996  Bowling Friendly            Hard            109               15
# 34997  Batting Friendly            Flat             82               16
# 34998  Batting Friendly           Green             58                5
# 34999          Balanced            Hard             69               10
#
#        wickets_out  runs_last_5_overs  overs_remaining  wickets_remaining  \
# 0                5                 68                8                  5
# 1                3                 55                4                  7
# 2                6                 32                7                  4
# 3                0                 48                7                 10
# 4                4                 57               15                  6
# ...            ...                ...              ...                ...
# 34995            3                 23                6                  7
# 34996            3                 48                5                  7
# 34997            4                 20                4                  6
# 34998            7                 30               15                  3
# 34999            3                 47               10                  7
#
#        run_rate  season  final_score
# 0         11.08    2024          229
# 1          4.75    2012          119
# 2          9.69    2017          195
# 3          5.00    2018          122
# 4          6.40    2020          115
# ...         ...     ...          ...
# 34995     10.57    2012          236
# 34996      7.27    2018          146
# 34997      5.12    2009          103
# 34998     11.60    2011          248
# 34999      6.90    2020          156
#
# [35000 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['match_id', 'batting_team', 'bowling_team', 'venue', 'pitch_type',
#        'pitch_condition', 'current_score', 'overs_completed', 'wickets_out',
#        'runs_last_5_overs', 'overs_remaining', 'wickets_remaining', 'run_rate',
#        'season', 'final_score'],
#       dtype='str')

# %%
df=pd.read_csv("C:\\Users\\mukes\\OneDrive\\Documents\\ML\\ipl data set.csv")
df

# %%
df["batting_team"].value_counts()
# Out:
# batting_team
# MI      3559
# DC      3557
# KKR     3535
# GT      3532
# PBKS    3516
# RR      3484
# CSK     3482
# LSG     3453
# RCB     3442
# SRH     3440
# Name: count, dtype: int64

# %%
df["bowling_team"].value_counts()
# Out:
# bowling_team
# LSG     3560
# SRH     3551
# MI      3524
# GT      3519
# PBKS    3494
# RR      3488
# RCB     3487
# KKR     3487
# CSK     3459
# DC      3431
# Name: count, dtype: int64

# %%
df["venue"].value_counts()
# Out:
# venue
# Eden Gardens              4473
# Arun Jaitley Stadium      4418
# Rajiv Gandhi Stadium      4395
# Chepauk Stadium           4387
# Wankhede Stadium          4363
# Sawai Mansingh Stadium    4358
# Chinnaswamy Stadium       4313
# Narendra Modi Stadium     4293
# Name: count, dtype: int64

# %%
df["pitch_condition"].value_counts()
# Out:
# pitch_condition
# Dry      7087
# Hard     7014
# Dusty    6996
# Green    6959
# Flat     6944
# Name: count, dtype: int64

# %%
ordinal_order = [["Green", "Dusty", "Dry", "Hard", "Flat"]]

# %%
preprocessor = ColumnTransformer(transformers=[
    
    ('tnf1',OrdinalEncoder(categories=ordinal_order),['pitch_condition']),
    ('tnf2',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','venue'])
],remainder='passthrough')

# %%
# Transform
x_train_transformed = preprocessor.fit_transform(x_train)
x_test_transformed = preprocessor.transform(x_test)

# Convert back to DataFrame
x_train_transformed = pd.DataFrame(
    x_train_transformed,
    columns=preprocessor.get_feature_names_out(),
    index=x_train.index
)

x_test_transformed = pd.DataFrame(
    x_test_transformed,
    columns=preprocessor.get_feature_names_out(),
    index=x_test.index
)

# %%
x_train_transformed
# Out:
#        tnf1__pitch_condition  tnf2__batting_team_DC  tnf2__batting_team_GT  \
# 18788                    0.0                    0.0                    0.0
# 776                      1.0                    0.0                    0.0
# 480                      3.0                    0.0                    0.0
# 30078                    3.0                    0.0                    0.0
# 29115                    2.0                    0.0                    0.0
# ...                      ...                    ...                    ...
# 16850                    3.0                    0.0                    0.0
# 6265                     4.0                    0.0                    0.0
# 11284                    2.0                    0.0                    1.0
# 860                      1.0                    0.0                    0.0
# 15795                    0.0                    0.0                    0.0
#
#        tnf2__batting_team_KKR  tnf2__batting_team_LSG  tnf2__batting_team_MI  \
# 18788                     0.0                     1.0                    0.0
# 776                       0.0                     0.0                    1.0
# 480                       0.0                     1.0                    0.0
# 30078                     1.0                     0.0                    0.0
# 29115                     0.0                     0.0                    0.0
# ...                       ...                     ...                    ...
# 16850                     1.0                     0.0                    0.0
# 6265                      0.0                     0.0                    0.0
# 11284                     0.0                     0.0                    0.0
# 860                       0.0                     0.0                    0.0
# 15795                     1.0                     0.0                    0.0
#
#        tnf2__batting_team_PBKS  tnf2__batting_team_RCB  tnf2__batting_team_RR  \
# 18788                      0.0                     0.0                    0.0
# 776                        0.0                     0.0                    0.0
# 480                        0.0                     0.0                    0.0
# 30078                      0.0                     0.0                    0.0
# 29115                      0.0                     0.0                    0.0
# ...                        ...                     ...                    ...
# 16850                      0.0                     0.0                    0.0
# 6265                       0.0                     0.0                    1.0
# 11284                      0.0                     0.0                    0.0
# 860                        1.0                     0.0                    0.0
# 15795                      0.0                     0.0                    0.0
#
#        tnf2__batting_team_SRH  ...  tnf2__venue_Rajiv Gandhi Stadium  \
# 18788                     0.0  ...                               0.0
# 776                       0.0  ...                               0.0
# 480                       0.0  ...                               1.0
# 30078                     0.0  ...                               1.0
# 29115                     1.0  ...                               0.0
# ...                       ...  ...                               ...
# 16850                     0.0  ...                               0.0
# 6265                      0.0  ...                               0.0
# 11284                     0.0  ...                               1.0
# 860                       0.0  ...                               0.0
# 15795                     0.0  ...                               0.0
#
#        tnf2__venue_Sawai Mansingh Stadium  tnf2__venue_Wankhede Stadium  \
# 18788                                 0.0                           0.0
# 776                                   0.0                           0.0
# 480                                   0.0                           0.0
# 30078                                 0.0                           0.0
# 29115                                 1.0                           0.0
# ...                                   ...                           ...
# 16850                                 0.0                           0.0
# 6265                                  0.0                           0.0
# 11284                                 0.0                           0.0
# 860                                   0.0                           1.0
# 15795                                 0.0                           0.0
#
#        remainder__current_score  remainder__overs_completed  \
# 18788                      64.0                         6.0
# 776                        54.0                        11.0
# 480                        65.0                         9.0
# 30078                     147.0                        17.0
# 29115                      69.0                        14.0
# ...                         ...                         ...
# 16850                      82.0                        13.0
# 6265                      129.0                        15.0
# 11284                     113.0                        17.0
# 860                        73.0                         7.0
# 15795                      69.0                        10.0
#
#        remainder__wickets_out  remainder__runs_last_5_overs  \
# 18788                     8.0                          36.0
# 776                       3.0                          17.0
# 480                       0.0                          36.0
# 30078                     7.0                          30.0
# 29115                     7.0                          48.0
# ...                       ...                           ...
# 16850                     8.0                          60.0
# 6265                      4.0                          21.0
# 11284                     4.0                          27.0
# 860                       5.0                          69.0
# 15795                     5.0                          38.0
#
#        remainder__overs_remaining  remainder__wickets_remaining  \
# 18788                        14.0                           2.0
# 776                           9.0                           7.0
# 480                          11.0                          10.0
# 30078                         3.0                           3.0
# 29115                         6.0                           3.0
# ...                           ...                           ...
# 16850                         7.0                           2.0
# 6265                          5.0                           6.0
# 11284                         3.0                           6.0
# 860                          13.0                           5.0
# 15795                        10.0                           5.0
#
#        remainder__run_rate
# 18788                10.67
# 776                   4.91
# 480                   7.22
# 30078                 8.65
# 29115                 4.93
# ...                    ...
# 16850                 6.31
# 6265                  8.60
# 11284                 6.65
# 860                  10.43
# 15795                 6.90
#
# [28000 rows x 33 columns]

# %%
model1=LinearRegression()
model1.fit(x_train_transformed,y_train)
y_predict=model1.predict(x_test_transformed)
print(r2_score(y_test,y_predict))
# Out:
# 0.905236490750599

# %%
model2=make_pipeline(PolynomialFeatures(degree=2),LinearRegression())
model2.fit(x_train_transformed,y_train)
y_predict2=model2.predict(x_test_transformed)
print(r2_score(y_test,y_predict2))
# Out:
# 0.9272910570715746

# %%
model3=make_pipeline(PolynomialFeatures(degree=3),LinearRegression())
model3.fit(x_train_transformed,y_train)
y_predict3=model3.predict(x_test_transformed)
print(r2_score(y_test,y_predict3))
# Out:
# 0.9315750166135703

# %%
x_test.tail()
# Out:
#       batting_team bowling_team                   venue pitch_condition  \
# 8045           KKR          CSK            Eden Gardens            Flat
# 33786           RR          LSG  Sawai Mansingh Stadium            Flat
# 13208           GT          LSG    Arun Jaitley Stadium           Dusty
# 24073          RCB          LSG    Rajiv Gandhi Stadium            Flat
# 20318          KKR           GT            Eden Gardens            Hard
#
#        current_score  overs_completed  wickets_out  runs_last_5_overs  \
# 8045             239               19            0                 22
# 33786            192               15            4                 69
# 13208             88               10            5                 30
# 24073            152               17            7                 62
# 20318             26                5            5                 33
#
#        overs_remaining  wickets_remaining  run_rate
# 8045                 1                 10     12.58
# 33786                5                  6     12.80
# 13208               10                  5      8.80
# 24073                3                  3      8.94
# 20318               15                  5      5.20

# %%
y_test.tail()
# Out:
# 8045     270
# 33786    270
# 13208    183
# 24073    168
# 20318     89
# Name: final_score, dtype: int64

# %%
new_data1 = pd.DataFrame([{
    'batting_team': 'RCB',
    'bowling_team': 'LSG',
    'venue': 'Rajiv Gandhi Stadium',
    'pitch_condition': 'Flat',
    'current_score': 152,
    'overs_completed': 17,
    'wickets_out': 7,
    'runs_last_5_overs': 62,
    'overs_remaining': 3,
    'wickets_remaining': 3,
    'run_rate': 8.94
}])


new_data_transformed = preprocessor.transform(new_data1)

prediction = model3.predict(new_data_transformed)

print("Predicted Final Score:", prediction[0])
# Out:
# c:\Users\mukes\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 18
#       1 new_data1 = pd.DataFrame([{
#       2     'batting_team': 'RCB',
#       3     'bowling_team': 'LSG',
#    (...)     12     'run_rate': 8.94
#      13 }])
#      16 new_data_transformed = preprocessor.transform(new_data1)
# ---> 18 prediction = model3.predict(new_data_transformed)
#      20 print("Predicted Final Score:", prediction[0])
#
# File c:\Users\mukes\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\pipeline.py:745, in Pipeline.predict(self, X, **params)
#     743 if not _routing_enabled():
#     744     for _, name, transform in self._iter(with_final=False):
# --> 745         Xt = transform.transform(Xt)
#     746     return self.steps[-1][1].predict(Xt, **params)
#     748 # metadata routing enabled
#
# File c:\Users\mukes\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\mukes\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_polynomial.py:424, in PolynomialFeatures.transform(self, X)
#     422 check_is_fitted(self)
#     423 xp, _, device_ = get_namespace_and_device(X)
# --> 424 X = validate_data(
#     425     self,
#     426     X,
#     427     order="F",
#     428     dtype=supported_float_dtypes(xp=xp, device=device_),
#     429     reset=False,
#     430     accept_sparse=("csr", "csc"),
#     431 )
#     433 n_samples, n_features = X.shape
#     434 max_int32 = xp.iinfo(xp.int32).max
#
# File c:\Users\mukes\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2923, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2920     out = X, y
#    2922 if not no_val_X and check_params.get("ensure_2d", True):
# -> 2923     _check_n_features(_estimator, X, reset=reset)
#    2925 return out
#
# File c:\Users\mukes\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2787, in _check_n_features(estimator, X, reset)
#    2784     return
#    2786 if n_features != estimator.n_features_in_:
# -> 2787     raise ValueError(
#    2788         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2789         f"is expecting {estimator.n_features_in_} features as input."
#    2790     )
#
# ValueError: X has 32 features, but PolynomialFeatures is expecting 33 features as input.

# %%
X=df[['batting_team','bowling_team','venue','pitch_condition','current_score','overs_completed','wickets_out','runs_last_5_overs','overs_remaining','run_rate']]
Y=df["wickets_remaining"]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
# Transform
X_train_transformed = preprocessor.fit_transform(X_train)
X_test_transformed = preprocessor.transform(X_test)

# Convert back to DataFrame
X_train_transformed = pd.DataFrame(
    X_train_transformed,
    columns=preprocessor.get_feature_names_out(),
    index=X_train.index
)

X_test_transformed = pd.DataFrame(
    X_test_transformed,
    columns=preprocessor.get_feature_names_out(),
    index=X_test.index
)

# %%
X_train_transformed
# Out:
#        tnf1__pitch_condition  tnf2__batting_team_DC  tnf2__batting_team_GT  \
# 18788                    0.0                    0.0                    0.0
# 776                      1.0                    0.0                    0.0
# 480                      3.0                    0.0                    0.0
# 30078                    3.0                    0.0                    0.0
# 29115                    2.0                    0.0                    0.0
# ...                      ...                    ...                    ...
# 16850                    3.0                    0.0                    0.0
# 6265                     4.0                    0.0                    0.0
# 11284                    2.0                    0.0                    1.0
# 860                      1.0                    0.0                    0.0
# 15795                    0.0                    0.0                    0.0
#
#        tnf2__batting_team_KKR  tnf2__batting_team_LSG  tnf2__batting_team_MI  \
# 18788                     0.0                     1.0                    0.0
# 776                       0.0                     0.0                    1.0
# 480                       0.0                     1.0                    0.0
# 30078                     1.0                     0.0                    0.0
# 29115                     0.0                     0.0                    0.0
# ...                       ...                     ...                    ...
# 16850                     1.0                     0.0                    0.0
# 6265                      0.0                     0.0                    0.0
# 11284                     0.0                     0.0                    0.0
# 860                       0.0                     0.0                    0.0
# 15795                     1.0                     0.0                    0.0
#
#        tnf2__batting_team_PBKS  tnf2__batting_team_RCB  tnf2__batting_team_RR  \
# 18788                      0.0                     0.0                    0.0
# 776                        0.0                     0.0                    0.0
# 480                        0.0                     0.0                    0.0
# 30078                      0.0                     0.0                    0.0
# 29115                      0.0                     0.0                    0.0
# ...                        ...                     ...                    ...
# 16850                      0.0                     0.0                    0.0
# 6265                       0.0                     0.0                    1.0
# 11284                      0.0                     0.0                    0.0
# 860                        1.0                     0.0                    0.0
# 15795                      0.0                     0.0                    0.0
#
#        tnf2__batting_team_SRH  ...  tnf2__venue_Narendra Modi Stadium  \
# 18788                     0.0  ...                                0.0
# 776                       0.0  ...                                0.0
# 480                       0.0  ...                                0.0
# 30078                     0.0  ...                                0.0
# 29115                     1.0  ...                                0.0
# ...                       ...  ...                                ...
# 16850                     0.0  ...                                1.0
# 6265                      0.0  ...                                0.0
# 11284                     0.0  ...                                0.0
# 860                       0.0  ...                                0.0
# 15795                     0.0  ...                                0.0
#
#        tnf2__venue_Rajiv Gandhi Stadium  tnf2__venue_Sawai Mansingh Stadium  \
# 18788                               0.0                                 0.0
# 776                                 0.0                                 0.0
# 480                                 1.0                                 0.0
# 30078                               1.0                                 0.0
# 29115                               0.0                                 1.0
# ...                                 ...                                 ...
# 16850                               0.0                                 0.0
# 6265                                0.0                                 0.0
# 11284                               1.0                                 0.0
# 860                                 0.0                                 0.0
# 15795                               0.0                                 0.0
#
#        tnf2__venue_Wankhede Stadium  remainder__current_score  \
# 18788                           0.0                      64.0
# 776                             0.0                      54.0
# 480                             0.0                      65.0
# 30078                           0.0                     147.0
# 29115                           0.0                      69.0
# ...                             ...                       ...
# 16850                           0.0                      82.0
# 6265                            0.0                     129.0
# 11284                           0.0                     113.0
# 860                             1.0                      73.0
# 15795                           0.0                      69.0
#
#        remainder__overs_completed  remainder__wickets_out  \
# 18788                         6.0                     8.0
# 776                          11.0                     3.0
# 480                           9.0                     0.0
# 30078                        17.0                     7.0
# 29115                        14.0                     7.0
# ...                           ...                     ...
# 16850                        13.0                     8.0
# 6265                         15.0                     4.0
# 11284                        17.0                     4.0
# 860                           7.0                     5.0
# 15795                        10.0                     5.0
#
#        remainder__runs_last_5_overs  remainder__overs_remaining  \
# 18788                          36.0                        14.0
# 776                            17.0                         9.0
# 480                            36.0                        11.0
# 30078                          30.0                         3.0
# 29115                          48.0                         6.0
# ...                             ...                         ...
# 16850                          60.0                         7.0
# 6265                           21.0                         5.0
# 11284                          27.0                         3.0
# 860                            69.0                        13.0
# 15795                          38.0                        10.0
#
#        remainder__run_rate
# 18788                10.67
# 776                   4.91
# 480                   7.22
# 30078                 8.65
# 29115                 4.93
# ...                    ...
# 16850                 6.31
# 6265                  8.60
# 11284                 6.65
# 860                  10.43
# 15795                 6.90
#
# [28000 rows x 32 columns]

# %%
model4=LinearRegression()
model4.fit(X_train_transformed,Y_train)
Y_predict=model4.predict(X_test_transformed)
print(r2_score(Y_test,Y_predict))
# Out:
# 1.0

# %%
model5=make_pipeline(PolynomialFeatures(degree=2),LinearRegression())
model5.fit(X_train_transformed,Y_train)
Y_predict2=model5.predict(X_test_transformed)
print(r2_score(Y_test,Y_predict2))
# Out:
# 1.0

# %%
new_data2 = pd.DataFrame([{
    'batting_team': 'KKR',
    'bowling_team': 'GT',
    'venue': 'Eden Gardens',
    'pitch_condition': 'Hard',
    'current_score': 26,
    'overs_completed': 5,
    'wickets_out': 5,
    'runs_last_5_overs': 33,
    'overs_remaining': 15,
   
    'run_rate': 5.20
}])


new_data_transformed2 = preprocessor.transform(new_data2)

prediction_wickets_remaining = model5.predict(new_data_transformed2)

print("Predicted Wickets Remaining:", prediction_wickets_remaining[0])
# Out:
# Predicted Wickets Remaining: 5.000000000000625
# c:\Users\mukes\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
